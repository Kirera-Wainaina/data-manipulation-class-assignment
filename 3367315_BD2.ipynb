# %% [markdown]
# # University of Stirling
#
# # ITNPBD2 Representing and Manipulating Data
#
# # Assignment Spring 2024
#
# # A Consultancy Job for JC Penney
#
# This notebook forms the assignment instructions and submission document of the assignment for ITNPBD2. Read the instructions carefully and enter code into the cells as indicated.
#
# You will need these five files, which were in the Zip file you downloaded from the course webpage:
#
# - jcpenney_reviewers.json
# - jcpenney_products.json
# - products.csv
# - reviews.csv
# - users.csv
#
# The data in these files describes products that have been sold by the American retail giant, JC Penney, and reviews by customers who bought them. Note that the product data is real, but the customer data is synthetic.
#
# Your job is to process the data, as requested in the instructions in the markdown cells in this notebook.

# %% [markdown]
# # Completing the Assignment
#
# Rename this file to be xxxxxx_BD2 where xxxxxx is your student number, then type your code and narrative description into the boxes provided. Add as many code and markdown cells as you need. The cells should contain:
#
# - **Text narrative describing what you did with the data**
# - **The code that performs the task you have described**
# - **Comments that explain your code**

# %% [markdown]
# # Marking Scheme
# The assessment will be marked against the university Common Marking Scheme (CMS)
#
# Here is a summary of what you need to achieve to gain a grade in the major grade bands:
#
# |Grade|Requirement|
# |:---|:---|
# | Fail | You will fail if your code does not run or does not achieve even the basics of the task. You may also fail if you submit code without either comments or a text explanation of what the code does.|
# | Pass | To pass, you must submit sufficient working code to show that you have mastered the basics of the task, even if not everything works completely. You must include some justifications for your choice of methods, but without mentioning alternatives. |
# | Merit | For a merit, your code must be mostly correct, with only small problems or parts missing, and your comments must be useful rather than simply re-stating the code in English. Most choices for methods and structures should be explained and alternatives mentioned. |
# | Distinction | For a distinction, your code must be working, correct, and well commented and shows an appreciation of style, efficiency and reliability. All choices for methods and structures are concisely justified and alternatives are given well thought considerations. For a distinction, your work should be good enough to present to executives at the company.|
#
# The full details of the CMS can be found here
#
# https://www.stir.ac.uk/about/professional-services/student-academic-and-corporate-services/academic-registry/academic-policy-and-practice/quality-handbook/assessment-policy-and-procedure/appendix-2-postgraduate-common-marking-scheme/
#
# Note that this means there are not certain numbers of marks allocated to each stage of the assignment. Your grade will reflect how well your solutions and comments demonstrate that you have achieved the learning outcomes of the task.

# %% [markdown]
# ## Submission
# When you are ready to submit, **print** your notebook as PDF (go to File -> Print Preview) in the Jupyter menu. Make sure you have run all the cells and that their output is displayed. Any lines of code or comments that are not visible in the pdf should be broken across several lines. You can then submit the file online.
#
# Late penalties will apply at a rate of three marks per day, up to a maximum of 7 days. After 7 days you will be given a mark of 0. Extensions will be considered under acceptable circumstances outside your control.
#
# ## Academic Integrity
#
# This is an individual assignment, and so all submitted work must be fully your own work.
#
# The University of Stirling is committed to protecting the quality and standards of its awards. Consequently, the University seeks to promote and nurture academic integrity, support staff academic integrity, and support students to understand and develop good academic skills that facilitate academic integrity.
#
# In addition, the University deals decisively with all forms of Academic Misconduct.
#
# Where a student does not act with academic integrity, their work or behaviour may demonstrate Poor Academic Practice or it may represent Academic Misconduct.
#
# ### Poor Academic Practice
#
# Poor Academic Practice is defined as: "The submission of any type of assessment with a lack of referencing or inadequate referencing which does not effectively acknowledge the origin of words, ideas, images, tables, diagrams, maps, code, sound and any other sources used in the assessment."
#
# ### Academic Misconduct
#
# Academic Misconduct is defined as: "any act or attempted act that does not demonstrate academic integrity and that may result in creating an unfair academic advantage for you or another person, or an academic disadvantage for any other member or member of the academic community."
#
# Plagiarism is presenting somebody else’s work as your own **and includes the use of artificial intelligence tools such as GPT or CoPilot**. Plagiarism is a form of academic misconduct and is taken very seriously by the University. Students found to have plagiarised work can have marks deducted and, in serious cases, even be expelled from the University. Do not submit any work that is not entirely your own. Do not collaborate with or get help from anybody else with this assignment.
#
# The University of Stirling's full policy on Academic Integrity can be found at:
#
# https://www.stir.ac.uk/about/professional-services/student-academic-and-corporate-services/academic-registry/academic-policy-and-practice/quality-handbook/academic-integrity-policy-and-academic-misconduct-procedure/

# %% [markdown]
# ## The Assignment
# Your task with this assignment is to use the data provided to demonstrate your Python data manipulation skills.
#
# There are three `.csv` files and two `.json` files so you can process different types of data. The files also contain unstructured data in the form of natural language in English and links to images that you can access from the JC Penney website (use the field called `product_image_urls`).
#
# Start with easy tasks to show you can read in a file, create some variables and data structures, and manipulate their contents. Then move onto something more interesting.
#
# Look at the data that we provided with this assessment and think of something interesting to do with it using whatever libraries you like. Describe what you decide to do with the data and why it might be interesting or useful to the company to do it.
#
# You can add additional data if you need to - either download it or access it using `requests`. Produce working code to implement your ideas in as many cells as you need below. There is no single right answer, the aim is to simply show you are competent in using python for data analysis. Exactly how you do that is up to you.
#
# For a distinction class grade, this must show originality, creative thinking, and insights beyond what you've been taught directly on the module.

# %% [markdown]
# ## Structure
# You may structure the project how you wish, but here is a suggested guideline to help you organise your work:
#
#  1. Data Exploration - Explore the data and show you understand its structure and relations
#  2. Data Validation - Check the quality of the data. Is it complete? Are there obvious errors?
#  3. Data Visualisation - Gain an overall understanding of the data with visualisations
#  4. Data Analysis = Set some questions and use the data to answer them
#  5. Data Augmentation - Add new data from another source to bring new insights to the data you already have

# %% [markdown]
# # Remember to make sure you are working completely on your own.
# # Don't work in a group or with a friend
# You may NOT use any automated code generation or analytics tools for this assignment, so do not use tools like GPT. You can look up the syntax for the functions you use, but you must write the code yourself and the comments must provide an insightful analysis of the results.

# %% [markdown]
# # Assignment Start

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# - We begin by loading the data to see how it is organized.
# - We will do this by creating a dataframe for each dataset using pandas

# %%
import pandas as pd

# %% [markdown]
# - For each dataset, we set an index and display a random set of 10 objects
# - We display the data type of the columns
# - We the `df.describe()` method to for summary statistics of the numerical columns

# %% [markdown]
# ### jcpenny_products.json

# %%
jcpenney_products = pd.read_json('jcpenney_products.json', lines=True)
jcpenney_products = jcpenney_products.set_index('uniq_id')
jcpenney_products.sample(10)
# Out:
#                                            sku  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2  pp5004900051
# a6feb07668938bcb511b20ea5c2823ba  pp5006490143
# 58217aa4b35b068928c684d238602a7f  pp5006380252
# cb409aaa1d3b93c1580fb56de00afad6  pp5005521446
# d969a8542122e1331e304b09f81a83f6  pp5006380337
# 8b5065d212e0e398f1db78f04e4bf361  pp5005030961
# bc7eea7fcbbc698c4e481ef1711cc516  pp5005141452
# dcba30baa7307c2d24e62e839b27ba33  pp5006240466
# f07596024758bd8fac696fb28fc9505a  pp5006460133
# a3f10a200366d6aa1582144d730e07a2  pp5001470715
#
#                                                                          name_title  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2               Sealy® Gilwood Plush - Mattress Only
# a6feb07668938bcb511b20ea5c2823ba          Jellifish 2-pk. Pajama Shorts - Boys 4-16
# 58217aa4b35b068928c684d238602a7f  Liz Claiborne® Road To Ibiza Sash Hipster Swim...
# cb409aaa1d3b93c1580fb56de00afad6            Mr. Coffee® Automatic Burr Mill Grinder
# d969a8542122e1331e304b09f81a83f6        Alfred Dunner® Essential Pull On Capri Pant
# 8b5065d212e0e398f1db78f04e4bf361  Casio® Mens Champagne Dial Black Resin Strap S...
# bc7eea7fcbbc698c4e481ef1711cc516              Donna Karan Cashmere Mist Body Lotion
# dcba30baa7307c2d24e62e839b27ba33              Decree® Lace T-Shirt or Bodycon Skirt
# f07596024758bd8fac696fb28fc9505a  St. John's Bay® Chevron High-Neck Tankini Swim...
# a3f10a200366d6aa1582144d730e07a2         Lee® Premium Select Relaxed Straight Jeans
#
#                                                                         description  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2  Combining the plush cushioning you crave with ...
# a6feb07668938bcb511b20ea5c2823ba  Perfect for lounging and winding down, your bo...
# 58217aa4b35b068928c684d238602a7f  Our Liz Claiborne hipster swim bottoms give yo...
# cb409aaa1d3b93c1580fb56de00afad6  Increase your coffee enjoyment by grinding you...
# d969a8542122e1331e304b09f81a83f6  You'll return to our Alfred Dunner pull-on cap...
# 8b5065d212e0e398f1db78f04e4bf361  Go anywhere with this sport watch that has lot...
# bc7eea7fcbbc698c4e481ef1711cc516  Live Colorfully is for the woman who lights up...
# dcba30baa7307c2d24e62e839b27ba33
# f07596024758bd8fac696fb28fc9505a
# a3f10a200366d6aa1582144d730e07a2  An update of the original, die-hard Lee jeans ...
#
#                                  list_price   sale_price  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2      701.0       315.45
# a6feb07668938bcb511b20ea5c2823ba      24.17        14.49
# 58217aa4b35b068928c684d238602a7f      54.65        38.01
# cb409aaa1d3b93c1580fb56de00afad6      68.58        53.20
# d969a8542122e1331e304b09f81a83f6      41.09        24.16
# 8b5065d212e0e398f1db78f04e4bf361                   24.12
# bc7eea7fcbbc698c4e481ef1711cc516                   60.61
# dcba30baa7307c2d24e62e839b27ba33             18.90-28.40
# f07596024758bd8fac696fb28fc9505a                   31.91
# a3f10a200366d6aa1582144d730e07a2                   87.20
#
#                                                   category  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2                     sealy
# a6feb07668938bcb511b20ea5c2823ba                   pajamas
# 58217aa4b35b068928c684d238602a7f                   bottoms
# cb409aaa1d3b93c1580fb56de00afad6          small appliances
# d969a8542122e1331e304b09f81a83f6                  view all
# 8b5065d212e0e398f1db78f04e4bf361                     casio
# bc7eea7fcbbc698c4e481ef1711cc516  body lotions & body oils
# dcba30baa7307c2d24e62e839b27ba33       outfits you'll love
# f07596024758bd8fac696fb28fc9505a            st. john's bay
# a3f10a200366d6aa1582144d730e07a2               guy's jeans
#
#                                                       category_tree  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2        jcpenney|for-the-home|sealy
# a6feb07668938bcb511b20ea5c2823ba                   jcpenney|pajamas
# 58217aa4b35b068928c684d238602a7f             jcpenney|women|bottoms
# cb409aaa1d3b93c1580fb56de00afad6          jcpenney|small appliances
# d969a8542122e1331e304b09f81a83f6            jcpenney|women|view all
# 8b5065d212e0e398f1db78f04e4bf361                     jcpenney|casio
# bc7eea7fcbbc698c4e481ef1711cc516  jcpenney|body lotions & body oils
# dcba30baa7307c2d24e62e839b27ba33       jcpenney|outfits you'll love
# f07596024758bd8fac696fb28fc9505a            jcpenney|st. john's bay
# a3f10a200366d6aa1582144d730e07a2               jcpenney|guy's jeans
#
#                                   average_product_rating  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2                   4.500
# a6feb07668938bcb511b20ea5c2823ba                   3.000
# 58217aa4b35b068928c684d238602a7f                   3.000
# cb409aaa1d3b93c1580fb56de00afad6                   3.800
# d969a8542122e1331e304b09f81a83f6                   3.125
# 8b5065d212e0e398f1db78f04e4bf361                   4.000
# bc7eea7fcbbc698c4e481ef1711cc516                   2.500
# dcba30baa7307c2d24e62e839b27ba33                   2.500
# f07596024758bd8fac696fb28fc9505a                   3.000
# a3f10a200366d6aa1582144d730e07a2                   3.500
#
#                                                                         product_url  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2  http://www.jcpenney.com/sealy-gilwood-plush-ma...
# a6feb07668938bcb511b20ea5c2823ba  http://www.jcpenney.com/jellifish-2-pk-pajama-...
# 58217aa4b35b068928c684d238602a7f  http://www.jcpenney.com/liz-claiborne-road-to-...
# cb409aaa1d3b93c1580fb56de00afad6  http://www.jcpenney.com/mr-coffee-automatic-bu...
# d969a8542122e1331e304b09f81a83f6  http://www.jcpenney.com/alfred-dunner-essentia...
# 8b5065d212e0e398f1db78f04e4bf361  http://www.jcpenney.com/casio-mens-champagne-d...
# bc7eea7fcbbc698c4e481ef1711cc516  http://www.jcpenney.com/donna-karan-cashmere-m...
# dcba30baa7307c2d24e62e839b27ba33  http://www.jcpenney.com/decree-lace-t-shirt-or...
# f07596024758bd8fac696fb28fc9505a  http://www.jcpenney.com/st-johns-bay-chevron-h...
# a3f10a200366d6aa1582144d730e07a2  http://www.jcpenney.com/lee-premium-select-rel...
#
#                                                                  product_image_urls  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2  http://s7d9.scene7.com/is/image/JCPenney/DP111...
# a6feb07668938bcb511b20ea5c2823ba  http://s7d2.scene7.com/is/image/JCPenney/DP012...
# 58217aa4b35b068928c684d238602a7f  http://s7d9.scene7.com/is/image/JCPenney/DP011...
# cb409aaa1d3b93c1580fb56de00afad6  http://s7d2.scene7.com/is/image/JCPenney/DP052...
# d969a8542122e1331e304b09f81a83f6  http://s7d9.scene7.com/is/image/JCPenney/DP122...
# 8b5065d212e0e398f1db78f04e4bf361  http://s7d2.scene7.com/is/image/JCPenney/DP012...
# bc7eea7fcbbc698c4e481ef1711cc516  http://s7d2.scene7.com/is/image/JCPenney/DP022...
# dcba30baa7307c2d24e62e839b27ba33  http://s7d2.scene7.com/is/image/JCPenney/DP102...
# f07596024758bd8fac696fb28fc9505a  http://s7d2.scene7.com/is/image/JCPenney/DP011...
# a3f10a200366d6aa1582144d730e07a2  http://s7d2.scene7.com/is/image/JCPenney/DP071...
#
#                                            brand  total_number_reviews  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2           Sealy                     2
# a6feb07668938bcb511b20ea5c2823ba  JELLIFISH KIDS                     1
# 58217aa4b35b068928c684d238602a7f   LIZ CLAIBORNE                     1
# cb409aaa1d3b93c1580fb56de00afad6      Mr. Coffee                     5
# d969a8542122e1331e304b09f81a83f6   Alfred Dunner                     8
# 8b5065d212e0e398f1db78f04e4bf361           Casio                     1
# bc7eea7fcbbc698c4e481ef1711cc516     DONNA KARAN                     8
# dcba30baa7307c2d24e62e839b27ba33          Decree                     8
# f07596024758bd8fac696fb28fc9505a  St. John's Bay                     7
# a3f10a200366d6aa1582144d730e07a2             LEE                     8
#
#                                                                             Reviews  \
# uniq_id
# f81af6eabb04b69f17b7912414f123d2  [{'User': 'aagf4423', 'Review': 'This is a goo...
# a6feb07668938bcb511b20ea5c2823ba  [{'User': 'adrd4334', 'Review': 'My son loves ...
# 58217aa4b35b068928c684d238602a7f  [{'User': 'qusu4233', 'Review': 'I love the co...
# cb409aaa1d3b93c1580fb56de00afad6  [{'User': 'qhex1312', 'Review': 'When you grin...
# d969a8542122e1331e304b09f81a83f6  [{'User': 'nbmi2334', 'Review': 'You never hav...
# 8b5065d212e0e398f1db78f04e4bf361  [{'User': 'cbsm1234', 'Review': 'Loved the wat...
# bc7eea7fcbbc698c4e481ef1711cc516  [{'User': 'idhy2324', 'Review': 'My aunt intro...
# dcba30baa7307c2d24e62e839b27ba33  [{'User': 'efyc1434', 'Review': 'This skirt wa...
# f07596024758bd8fac696fb28fc9505a  [{'User': 'gpcn4233', 'Review': 'I love this b...
# a3f10a200366d6aa1582144d730e07a2  [{'User': 'silv1313', 'Review': 'Depending on ...
#
#                                                                         Bought With
# uniq_id
# f81af6eabb04b69f17b7912414f123d2  [362b2c5a268576ddf12001ce5b1114b9, 093737e747a...
# a6feb07668938bcb511b20ea5c2823ba  [c3a3a8abddbafba83d4449cd56435f13, 826818bfa10...
# 58217aa4b35b068928c684d238602a7f  [78768173716a0ed3ac1f6cbc91b7309e, 242bca6c23f...
# cb409aaa1d3b93c1580fb56de00afad6  [6c0768a7328552a403b0c5f249b85b36, 17a1d41a9d6...
# d969a8542122e1331e304b09f81a83f6  [0ca5ad2a218f59eb83eec1e248a0782d, 9869fc8da14...
# 8b5065d212e0e398f1db78f04e4bf361  [cf5febde51884653ab00471a8e2c35f1, 698ad66a40e...
# bc7eea7fcbbc698c4e481ef1711cc516  [55d54e71d8ce10629019d9b67e84270d, fdfbbf901e8...
# dcba30baa7307c2d24e62e839b27ba33  [be7c99cce6c131bf95db060e18755acb, bf6d19acda7...
# f07596024758bd8fac696fb28fc9505a  [133eda876ccc6807514a1c112288995f, de8d6986910...
# a3f10a200366d6aa1582144d730e07a2  [998370a0f80a71d970b4d4601d41cfb3, 5f567220393...

# %% [markdown]
# - Displayed above is the list of products.
# - It is worth noting that each product has a reviews column that consists of its reviews.
# - Each review has the keys:
#     1. User
#     2. Review
#     3. Score

# %%
jcpenney_products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7982 entries, b6c0b6bea69c722939585baeac73c13d to 2cc49292b44cc12fe22206440d3e7472
# Data columns (total 14 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   sku                     7982 non-null   object
#  1   name_title              7982 non-null   object
#  2   description             7982 non-null   object
#  3   list_price              7982 non-null   object
#  4   sale_price              7982 non-null   object
#  5   category                7982 non-null   object
#  6   category_tree           7982 non-null   object
#  7   average_product_rating  7982 non-null   float64
#  8   product_url             7982 non-null   object
#  9   product_image_urls      7982 non-null   object
#  10  brand                   7982 non-null   object
#  11  total_number_reviews    7982 non-null   int64
#  12  Reviews                 7982 non-null   object
#  13  Bought With             7982 non-null   object
# dtypes: float64(1), int64(1), object(12)
# memory usage: 935.4+ KB

# %% [markdown]
# Some data types need to be converted into other data types for easier manipulation

# %%
# Convert list price to float type
jcpenney_products['list_price'] = [float(price) if price else None for price in jcpenney_products['list_price']];

# %%
jcpenney_products.describe()
# Out:
#          list_price  average_product_rating  total_number_reviews
# count   5816.000000             7982.000000           7982.000000
# mean     144.776618                2.988683              4.893886
# std      499.223719                0.911673              3.314284
# min      -65.270000                1.000000              1.000000
# 25%       40.700000                2.500000              2.000000
# 50%       58.010000                3.000000              4.000000
# 75%       87.020000                3.500000              8.000000
# max    17122.170000                5.000000             23.000000

# %% [markdown]
# - The lowest `list_price` is a negative value which is impossible
# - We remove the negative value and make it positive

# %%
# clean list_price by removing the negative prices
jcpenney_products['list_price'] = [abs(price) if price else None for price in jcpenney_products['list_price']]

# %%
jcpenney_products.describe()
# Out:
#          list_price  average_product_rating  total_number_reviews
# count   5816.000000             7982.000000           7982.000000
# mean     145.424555                2.988683              4.893886
# std      499.035327                0.911673              3.314284
# min        8.010000                1.000000              1.000000
# 25%       41.042500                2.500000              2.000000
# 50%       58.010000                3.000000              4.000000
# 75%       87.020000                3.500000              8.000000
# max    17122.170000                5.000000             23.000000

# %% [markdown]
# ### jcpenney_reviewers.json

# %%
reviewers = pd.read_json('jcpenney_reviewers.json', lines=True)
jcpenney_reviewers = reviewers.set_index('Username')
jcpenney_reviewers.sample(10)
# Out:
#                  DOB                   State  \
# Username
# bwex1342  04.08.1966          American Samoa
# cqqx3323  07.08.1952              Washington
# rpkg1243  04.08.1966           New Hampshire
# ynhl3313  07.08.1954               Louisiana
# jqiy1113  30.07.1987                Michigan
# qrqu3432  03.08.1969                Nebraska
# vkcs1323  04.08.1965               Tennessee
# okun1224  06.08.1956  Minor Outlying Islands
# wrlo2431  30.07.1984           Massachusetts
# sydn4322  02.08.1974            South Dakota
#
#                                                    Reviewed
# Username
# bwex1342                                                 []
# cqqx3323  [9b8426283a6fb894fa34f934624d6b27, 4d353b12ea3...
# rpkg1243                                                 []
# ynhl3313                 [491dd6aafaa85e4f0ac9465b5158b6ef]
# jqiy1113  [923cfeb6548f6e9f83ad4777b23328ed, 7593940d127...
# qrqu3432  [6b64e76661084364cf8218cf932cff09, bb1df6c26c1...
# vkcs1323                                                 []
# okun1224                 [e0ebe7e1f3fbd0ce56a37e623fb09b68]
# wrlo2431  [2271f84d674c40d278d120da5ae0b15f, efc281c7531...
# sydn4322  [3d5fdd340a99d46d920a32686a2e839a, b4f687c4a7a...

# %%
jcpenney_reviewers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, bkpn1412 to yuoc2324
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DOB       5000 non-null   object
#  1   State     5000 non-null   object
#  2   Reviewed  5000 non-null   object
# dtypes: object(3)
# memory usage: 156.2+ KB

# %%
# Convert the DOB column to datetime
jcpenney_reviewers['DOB'] = pd.to_datetime(jcpenney_reviewers['DOB'], format="%d.%m.%Y")

# %%
jcpenney_reviewers.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, bkpn1412 to yuoc2324
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   DOB       5000 non-null   datetime64[ns]
#  1   State     5000 non-null   object
#  2   Reviewed  5000 non-null   object
# dtypes: datetime64[ns](1), object(2)
# memory usage: 156.2+ KB

# %%
jcpenney_reviewers.describe()
# Out:
#                               DOB
# count                        5000
# mean   1975-10-28 03:53:16.800000
# min           1950-08-08 00:00:00
# 25%           1962-08-05 00:00:00
# 50%           1975-08-02 00:00:00
# 75%           1988-07-29 00:00:00
# max           2001-07-26 00:00:00

# %% [markdown]
# ### products.csv

# %%
products = pd.read_csv('products.csv', index_col='Uniq_id')
products.sample(10)
# Out:
#                                            SKU  \
# Uniq_id
# 1f57f3aab52a5f30ed55339af6734fc9  pp5003980251
# 174959316353c27d4017e9ef4ccdd735  pp5003950575
# 27ecd711872d30d910201af7312774db  pp5006242484
# de70462752acc5952fbbf3ca7aab365d  pp5004990211
# 4646d75125de672191514ca5fbf4325f  pp5006221881
# 3151ae581340eaf05d15a62cc7ed55f1  pp5005090441
# 1cde7c8df7d14d77806f1f0929670aef  pp5006650494
# 96d4001b8000eab965d0ed3ddccbe27d  pp5006162020
# 89d2894a56e35275f217a4499072a31a  pp5006830157
# 81b913f04577d01691e3a30da89eed5f  pp5006310626
#
#                                                                                Name  \
# Uniq_id
# 1f57f3aab52a5f30ed55339af6734fc9  Intelligent Design Sabrina Damask Duvet Cover Set
# 174959316353c27d4017e9ef4ccdd735  Levinsohn Mattress Guard™ Waterproof Mattress ...
# 27ecd711872d30d910201af7312774db                  Mixit™ Scroll Bling Wedge Sandals
# de70462752acc5952fbbf3ca7aab365d  American Tourister® iLite Extreme 21 Spinner U...
# 4646d75125de672191514ca5fbf4325f    Xersion™ Long-Sleeve High-Low Sweatshirt - Plus
# 3151ae581340eaf05d15a62cc7ed55f1  adidas® Mens 3-pk. climacool® Superlite No-Sho...
# 1cde7c8df7d14d77806f1f0929670aef  St. Johns Bay® Short-Sleeve Tie Front Peasant ...
# 96d4001b8000eab965d0ed3ddccbe27d                       Farberware® 4-Cup Percolator
# 89d2894a56e35275f217a4499072a31a  Azul By Maxine Of Hollywood® Stripe It Or Not ...
# 81b913f04577d01691e3a30da89eed5f             Arizona Ginger Rhinestone Flat Sandals
#
#                                                                         Description  \
# Uniq_id
# 1f57f3aab52a5f30ed55339af6734fc9  A pop of color! Make a fashion statement with ...
# 174959316353c27d4017e9ef4ccdd735  Keep your mattress clean and fresh with this w...
# 27ecd711872d30d910201af7312774db  Rhinestones and beads set in a scroll pattern ...
# de70462752acc5952fbbf3ca7aab365d  With four multi-directional airflow spinner wh...
# 4646d75125de672191514ca5fbf4325f  Throw on our seamed graphic sweatshirt for com...
# 3151ae581340eaf05d15a62cc7ed55f1  These no-show performance socks keep you in th...
# 1cde7c8df7d14d77806f1f0929670aef  A rustic feel in a cute, modern design makes o...
# 96d4001b8000eab965d0ed3ddccbe27d  Enjoy the full and robust flavor of percolator...
# 89d2894a56e35275f217a4499072a31a  Get ready to take a dip or enjoy some time in ...
# 81b913f04577d01691e3a30da89eed5f  Pretty flats with irresistible rhinestones mak...
#
#                                    Price  Av_Score
# Uniq_id
# 1f57f3aab52a5f30ed55339af6734fc9     NaN      3.40
# 174959316353c27d4017e9ef4ccdd735     NaN      2.50
# 27ecd711872d30d910201af7312774db   29.01      3.25
# de70462752acc5952fbbf3ca7aab365d  241.72      3.00
# 4646d75125de672191514ca5fbf4325f   56.76      3.80
# 3151ae581340eaf05d15a62cc7ed55f1   16.55      3.00
# 1cde7c8df7d14d77806f1f0929670aef   43.51      3.00
# 96d4001b8000eab965d0ed3ddccbe27d     NaN      3.20
# 89d2894a56e35275f217a4499072a31a   62.85      1.00
# 81b913f04577d01691e3a30da89eed5f   47.30      3.00

# %%
products.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 7982 entries, b6c0b6bea69c722939585baeac73c13d to 2cc49292b44cc12fe22206440d3e7472
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   SKU          7915 non-null   object
#  1   Name         7982 non-null   object
#  2   Description  7439 non-null   object
#  3   Price        5816 non-null   float64
#  4   Av_Score     7982 non-null   float64
# dtypes: float64(2), object(3)
# memory usage: 374.2+ KB

# %%
products.describe()
# Out:
#               Price     Av_Score
# count   5816.000000  7982.000000
# mean     144.776618     2.988683
# std      499.223719     0.911673
# min      -65.270000     1.000000
# 25%       40.700000     2.500000
# 50%       58.010000     3.000000
# 75%       87.020000     3.500000
# max    17122.170000     5.000000

# %%
# Ensure Price doesn't have a negative price value
products['Price'] = [abs(price) for price in products['Price']]

# %%
products.describe()
# Out:
#               Price     Av_Score
# count   5816.000000  7982.000000
# mean     145.424555     2.988683
# std      499.035327     0.911673
# min        8.010000     1.000000
# 25%       41.042500     2.500000
# 50%       58.010000     3.000000
# 75%       87.020000     3.500000
# max    17122.170000     5.000000

# %% [markdown]
# ### reviews.csv

# %%
reviews = pd.read_csv('reviews.csv', index_col='Uniq_id')
reviews.sample(10)
# Out:
#                                   Username  Score  \
# Uniq_id
# 0e7e287af554049f9b7e4c90c3c40c1e  kcqh1322      0
# c8d7383fad39e31a2284b99e55ad0824  igqu1322      1
# 939f7a07d4d4b74f9f7ad4eb62863f93  enal3213      3
# 36e3654ac4d09dd49dbde7364d5e5536  nmdv1314      2
# 8df9e42123392d5a34cb8a813897e5fc  noel2242      2
# 46fd494ec7c37f17ec9c703c0109682e  lvez3443      0
# 93d7e9820aca9ec65eaeeff79952d82f  sxdk3132      2
# b604be127fe2d4bc0fdd6e1307f18f4b  xvsq4114      3
# be54df857e46c3d04083a1a5442873c2  ywpm1212      1
# 62420a014d53e67d40d35b8dd67ad786  aieu1434      2
#
#                                                                              Review
# Uniq_id
# 0e7e287af554049f9b7e4c90c3c40c1e  I really like the style and color of these boy...
# c8d7383fad39e31a2284b99e55ad0824  I ordered the navy print shirt and although it...
# 939f7a07d4d4b74f9f7ad4eb62863f93  I have never done a review before....got a ros...
# 36e3654ac4d09dd49dbde7364d5e5536  Black hands and numbers make this watch very e...
# 8df9e42123392d5a34cb8a813897e5fc  Pillow matches quilt / shams perfectly.Soft. L...
# 46fd494ec7c37f17ec9c703c0109682e  These pants are a great value and are true to ...
# 93d7e9820aca9ec65eaeeff79952d82f  My 14-year old child loves these pants. He lik...
# b604be127fe2d4bc0fdd6e1307f18f4b  I like the way these pants feel and look, good...
# be54df857e46c3d04083a1a5442873c2  I love this plush blanket my husband love it, ...
# 62420a014d53e67d40d35b8dd67ad786  The best socks anywhere! I found these socks w...

# %%
reviews.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 39063 entries, b6c0b6bea69c722939585baeac73c13d to 2cc49292b44cc12fe22206440d3e7472
# Data columns (total 3 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Username  39063 non-null  object
#  1   Score     39063 non-null  int64
#  2   Review    39063 non-null  object
# dtypes: int64(1), object(2)
# memory usage: 1.2+ MB

# %%
reviews.describe()
# Out:
#               Score
# count  39063.000000
# mean       1.487648
# std        1.400332
# min        0.000000
# 25%        0.000000
# 50%        1.000000
# 75%        2.000000
# max        5.000000

# %% [markdown]
# ### users.csv

# %%
users = pd.read_csv('users.csv', index_col='Username')
users.sample(10)
# Out:
#                  DOB                State
# Username
# jvkt4412  04.08.1964              Arizona
# onet4224  29.07.1991              Montana
# isfs2222  01.08.1977            Louisiana
# ngos2134  29.07.1991             Missouri
# utzt1343  27.07.1996              Florida
# alhe1223  01.08.1978             Missouri
# qojv4313  04.08.1964             Colorado
# sqkq2331  26.07.2001  U.S. Virgin Islands
# ajes3331  26.07.2001             Delaware
# xpsp4232  27.07.1999          Puerto Rico

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, bkpn1412 to yuoc2324
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DOB     5000 non-null   object
#  1   State   5000 non-null   object
# dtypes: object(2)
# memory usage: 117.2+ KB

# %%
# convert DOB to datetime object
users['DOB'] = pd.to_datetime(users['DOB'], format="%d.%m.%Y")

# %%
users.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5000 entries, bkpn1412 to yuoc2324
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   DOB     5000 non-null   datetime64[ns]
#  1   State   5000 non-null   object
# dtypes: datetime64[ns](1), object(1)
# memory usage: 117.2+ KB

# %%
users.describe()
# Out:
#                               DOB
# count                        5000
# mean   1975-10-28 03:53:16.800000
# min           1950-08-08 00:00:00
# 25%           1962-08-05 00:00:00
# 50%           1975-08-02 00:00:00
# 75%           1988-07-29 00:00:00
# max           2001-07-26 00:00:00

# %% [markdown]
# ## Data Visualization

# %% [markdown]
# - In this section we start looking at relationships between variables
# - We do this through charts

# %%
pd.plotting.scatter_matrix(jcpenney_products);
